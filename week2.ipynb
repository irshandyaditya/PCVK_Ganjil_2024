# %% [markdown]
# <a href="https://colab.research.google.com/github/irshandyaditya/PCVK_Ganjil_2024/blob/Week-2/week2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Praktikum
# ## Langkah (Step) 1

# %%
from google.colab import drive

# Accesing My Google Drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import cv2 as cv
from google.colab.patches import cv2_imshow
from skimage import io
import matplotlib.pyplot as plt
import numpy as np
img = cv.imread('/content/drive/MyDrive/PCVK/img/kucing.jpeg')
plt.imshow(img)          #perhatikan hasilnya adalah citra dgn channel warna BGR

# %%
img2 = img
img3 = cv.cvtColor(img,cv.COLOR_BGR2RGB)    #Konversi channel BGR -> RGB
plt.imshow(img3)

# %%
img_gray = cv.imread('/content/drive/MyDrive/PCVK/img/kucing.jpeg', cv.IMREAD_GRAYSCALE)
plt.imshow(img_gray)

# %%
plt.imshow(img_gray, cmap='gray')

# %%
plt.imshow(img_gray, cmap='magma')

# %%
img4 = cv.resize(cv.cvtColor(img, cv.COLOR_BGR2RGB), (512,1024))
plt.imshow(img4)

# %%
img5 = cv.flip(cv.cvtColor(img, cv.COLOR_BGR2RGB),0)

#simpan File image
#cv.imwrite('/content/drive/MyDrive/PCVK/img/kucing.jpeg',img5)

#tampilkan plot dengan ukuran yang lebih besar
fig = plt.figure(figsize=(10,10))       #ubah-ubah ukuran (10,10) sesuai kebutuhan
ax = fig.add_subplot(111)
ax.imshow(img5)

# %%
black_img = np.zeros(shape=(512,512,3),dtype=np.int16)
plt.imshow(black_img)

# %%
#perhatikan koordinat titik2 pt1 dan pt2
cv.rectangle(black_img,pt1=(348,0),pt2=(510,150),color=(0,255,0),thickness=10)
plt.imshow(black_img)

# %%
cv.rectangle(black_img,pt1=(200,200),pt2=(300,300),color=(0,0,255),thickness=15)
plt.imshow(black_img)

# %%
cv.circle(black_img,center=(100,100),radius=50,color=(255,0,0),thickness=0)
plt.imshow(black_img)

# %%
cv.line(black_img,pt1=(0,0),pt2=(512,512),color=(255,255,255),thickness=5)
plt.imshow(black_img)

# %%
font = cv.FONT_HERSHEY_SIMPLEX
cv.putText(black_img,text='Hello',org=(10,500),fontFace=font,fontScale=4,color=(255,255,0),thickness=2,lineType=cv.LINE_AA)
plt.imshow(black_img)

# %%
black_img2=np.zeros(shape=(512,512,3),dtype=np.int32)
plt.imshow(black_img2)

# %%
vertices = np.array([[100,300],[200,200],[400,300],[200,400]],dtype=np.int32)
vertices
# Out:
# array([[100, 300],
#        [200, 200],
#        [400, 300],
#        [200, 400]], dtype=int32)

# %%
pts = vertices.reshape((-1,1,2)) #nilai 2 menunjukkan bahwa tiap titik dibuat 3 channel yang memiliki R, G, dan B
pts
# Out:
# array([[[100, 300]],
#
#        [[200, 200]],
#
#        [[400, 300]],
#
#        [[200, 400]]], dtype=int32)

# %%
cv.polylines(black_img2,[pts],isClosed=True,color=(255,0,0),thickness=5)
plt.imshow(black_img2)

# %% [markdown]
# ## Tugas

# %%
# nomor 1
# Red-Blue
img_rb = cv.imread('/content/drive/MyDrive/PCVK/img/kucing.jpeg',cv.IMREAD_GRAYSCALE)
plt.imshow(img_rb, cmap='RdBu')

# %%
#green-blue
# Green-Blue
img_gb = cv.imread('/content/drive/MyDrive/PCVK/img/kucing.jpeg',cv.IMREAD_GRAYSCALE)
plt.imshow(img_gb, cmap='GnBu')

# %%
# nomor 2
img = cv.imread('/content/drive/MyDrive/PCVK/img/kucing.jpeg', cv.IMREAD_GRAYSCALE)
img = cv.cvtColor(img, cv.COLOR_BGR2RGB)
plt.imshow(img[20:115,25:120])

# %%
# nomor 3
plt.imshow(img[5:30])

# %%
# nomor 4
img_ktk = cv.cvtColor(img,cv.COLOR_BGR2RGB)
cv.rectangle(img_ktk, pt1=(100,100), pt2=(40,170), color=(0,255,255), thickness=10)
cv.rectangle(img_ktk, pt1=(200,100), pt2=(400,200), color=(0,255,0),thickness=10)
cv.rectangle(img_ktk, pt1=(400,250), pt2=(300,300), color=(255,255,255),thickness=10)
cv.rectangle(img_ktk, pt1=(100,320), pt2=(160,260), color=(255,0,0),thickness=10)
cv.rectangle(img_ktk, pt1=(620,190), pt2=(400,450), color=(0,0,255),thickness=10)
plt.imshow(img_ktk)

# %%
# nomor 5
img_t = cv.flip(cv.cvtColor(img,cv.COLOR_BGR2RGB),0)

fig = plt.figure(figsize=(7,7))
ax = fig.add_subplot(111)
ax.imshow(img_t)

# %%
img_1 = cv.imread('/content/drive/MyDrive/PCVK/img/kucing.jpeg')
plt.imshow(img_1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-41-d3ff9d4ec1e0> in <cell line: 2>()
#       1 img_1 = cv.imread('/content/drive/MyDrive/PCVK/img/foto_saya.jpeg')
# ----> 2 plt.imshow(img_1)
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/pyplot.py in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, interpolation_stage, filternorm, filterrad, resample, url, data, **kwargs)
#    2693         interpolation_stage=None, filternorm=True, filterrad=4.0,
#    2694         resample=None, url=None, data=None, **kwargs):
# -> 2695     __ret = gca().imshow(
#    2696         X, cmap=cmap, norm=norm, aspect=aspect,
#    2697         interpolation=interpolation, alpha=alpha, vmin=vmin,
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
# ...

# %%
img_rgb = cv.cvtColor(img_1,cv.COLOR_BGR2RGB)
plt.imshow(img_rgb)

# %%
cv.rectangle(img_rgb,pt1=(250,50),pt2=(500,300),color=(0,0,255),thickness=15)
plt.imshow(img_rgb)

# %%
cv.circle(img_rgb,center=(375,175),radius=75,color=(255,0,0),thickness=8)
plt.imshow(img_rgb)

# %%
cv.rectangle(img_rgb,pt1=(100,300),pt2=(10,350),color=(0,255,0),thickness=10)
plt.imshow(img_rgb)
